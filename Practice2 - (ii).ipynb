# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer

# %%
df=pd.read_csv('D:\SEM 3\Data Preprocessing Lab\zomato_dataset.csv')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name Country Code              City  \
# 0           6317637          Le Petit Souffle          162       Makati City
# 1           6304287          Izakaya Kikufuji          162       Makati City
# 2           6300002                         ?          162                 ?
# 3           6318506                      Ooma            ?                 ?
# 4           6314302                         ?            ?  Mandaluyong City
# ...             ...                       ...          ...               ...
# 9546        5915730               Naml? Gurme            ?                 ?
# 9547        5908749               Ceviz A?ac?            ?          ?stanbul
# 9548        5915807                     Huqqa          208                 ?
# 9549        5916112                         ?            ?          ?stanbul
# 9550        5927402  Walter's Coffee Roastery          208          ?stanbul
#
# ...

# %%
df.replace('?', np.nan, inplace=True)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name Country Code              City  \
# 0           6317637          Le Petit Souffle          162       Makati City
# 1           6304287          Izakaya Kikufuji          162       Makati City
# 2           6300002                       NaN          162               NaN
# 3           6318506                      Ooma          NaN               NaN
# 4           6314302                       NaN          NaN  Mandaluyong City
# ...             ...                       ...          ...               ...
# 9546        5915730               Naml? Gurme          NaN               NaN
# 9547        5908749               Ceviz A?ac?          NaN          ?stanbul
# 9548        5915807                     Huqqa          208               NaN
# 9549        5916112                       NaN          NaN          ?stanbul
# 9550        5927402  Walter's Coffee Roastery          208          ?stanbul
#
# ...

# %% [markdown]
# ### Dropping all the rows with null value

# %%
df1=df.dropna()
df1
# Out:
#       Restaurant ID           Restaurant Name Country Code         City  \
# 0           6317637          Le Petit Souffle          162  Makati City
# 1           6304287          Izakaya Kikufuji          162  Makati City
# 9550        5927402  Walter's Coffee Roastery          208     ?stanbul
#
#                                                 Address  \
# 0     Third Floor; Century City Mall; Kalayaan Avenu...
# 1     Little Tokyo; 2277 Chino Roces Avenue; Legaspi...
# 9550  Cafea?a Mahallesi; Bademalt? Sokak; No 21/B; K...
#
#                                         Locality  \
# 0      Century City Mall; Poblacion; Makati City
# 1     Little Tokyo; Legaspi Village; Makati City
# 9550                                        Moda
#
#                                        Locality Verbose    Longitude  \
# 0     Century City Mall; Poblacion; Makati City; Mak...   121.027535
# 1     Little Tokyo; Legaspi Village; Makati City; Ma...   121.014101
# ...

# %% [markdown]
# ### Choose the right Data Imputation (replacement strategy) for the missing data.

# %%
df.isna().sum()
# Out:
# Restaurant ID              0
# Restaurant Name         4985
# Country Code            4972
# City                    4840
# Address                 4855
# Locality                4828
# Locality Verbose        4974
# Longitude               4911
# Latitude                4855
# Cuisines                4932
# Average Cost for two    4893
# Currency                4894
# Price range             4931
# Aggregate rating        4861
# Rating color            4935
# Rating text             4965
# Votes                   4918
# dtype: int64

# %%
df2=df

# %% [markdown]
# #### Imputation on Votes

# %%
import random

# %%
if df2['Votes'].isna:
    df2['Votes'].fillna(random.randint(0,8000),inplace=True)

# %%
df2['Votes'].isna().sum()
# Out:
# 0

# %%
df2['Votes']
# Out:
# 0        314
# 1        591
# 2        270
# 3        365
# 4        229
#         ...
# 9546     788
# 9547    1034
# 9548     661
# 9549     901
# 9550     591
# Name: Votes, Length: 9551, dtype: object

# %%
df2
# Out:
#       Restaurant ID           Restaurant Name Country Code       City  \
# 0           6317637          Le Petit Souffle          162      Floor
# 1           6304287          Izakaya Kikufuji          162      Tokyo
# 2           6300002                       NaN          162         La
# 3           6318506                      Ooma          NaN      Floor
# 4           6314302                       NaN          NaN      Floor
# ...             ...                       ...          ...        ...
# 9546        5915730               Naml? Gurme          NaN  Mahallesi
# 9547        5908749               Ceviz A?ac?          NaN        NaN
# 9548        5915807                     Huqqa          208        NaN
# 9549        5916112                       NaN          NaN        NaN
# 9550        5927402  Walter's Coffee Roastery          208  Mahallesi
#
#                                                 Address  \
# 0     Third Floor; Century City Mall; Kalayaan Avenu...
# ...

# %%
df2['Votes'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Imputation on City

# %%
df2
# Out:
#       Restaurant ID           Restaurant Name Country Code       City  \
# 0           6317637          Le Petit Souffle          162      Floor
# 1           6304287          Izakaya Kikufuji          162      Tokyo
# 2           6300002                       NaN          162         La
# 3           6318506                      Ooma          NaN      Floor
# 4           6314302                       NaN          NaN      Floor
# ...             ...                       ...          ...        ...
# 9546        5915730               Naml? Gurme          NaN  Mahallesi
# 9547        5908749               Ceviz A?ac?          NaN        NaN
# 9548        5915807                     Huqqa          208        NaN
# 9549        5916112                       NaN          NaN        NaN
# 9550        5927402  Walter's Coffee Roastery          208  Mahallesi
#
#                                                 Address  \
# 0     Third Floor; Century City Mall; Kalayaan Avenu...
# ...

# %%
df2['City']
# Out:
# 0           Floor
# 1           Tokyo
# 2              La
# 3           Floor
# 4           Floor
#           ...
# 9546    Mahallesi
# 9547          NaN
# 9548          NaN
# 9549          NaN
# 9550    Mahallesi
# Name: City, Length: 9551, dtype: object
